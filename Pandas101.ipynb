# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratchadakorn26/python_dataviz2023/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Meta data = Data that describtion data
#
# ใช้อธิบายช้อมูล
#
# ## CSV = Comma Separated Values
# ในการจะใส่ค่าแต่ละค่า จะใช้  comma ในการแย่ง

# %% [markdown]
# .csv = Comma Separated Values

# %% [markdown]
# data.go.th

# %% [markdown]
# # นำ Data เข้า
# - upload to colab  # กรณีใช้เเค่ครั้งเดียว
# - link with google drive

# %% [markdown]
# ## upload to colab

# %%
data0 = pd.read_csv('/content/csv.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-eb95db60e09b> in <cell line: 1>()
# ----> 1 data0 = pd.read_csv('/content/csv.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/csv.csv'

# %%
data0

# %%
data0.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-db35e4daf9d3> in <cell line: 1>()
# ----> 1 data0.head(20)
#
# NameError: name 'data0' is not defined

# %%
data0.tail()

# %%
data0.shape

# %%
data0.describe()

# %% [markdown]
# ## link with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')  # mount =  เชื่อมไดร์ฟ

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Dataviz23DATA/csv.csv')
data1.head()

# %%
data1.head(10)  # ดูหัวตาราง จากแถวบน 10 แถวแรก นับจาก 0-9

# %%
data1.tail(10) # ดูท้ายตาราง จากข้างล่าง

# %%
data1.shape # ดูขนาด กี่เเถวกี่หลัก

# %%
data1.describe()

# %% [markdown]
# NaN = Not a Number

# %% [markdown]
# # ชี้ค่าในตาราง (indexing)

# %% [markdown]
# ##มุมมองตาราง df[columns][row]

# %% [markdown]
# df คือ dataframe เป็นชื่อ Data Structure ที่ panda ใช้

# %%
data1['Budget_resource']##Budget_resource คือชื่อคอลัมที่เราต้องการหา

# %%
data1['Budget_resource'][690]

# %%
 data1.iloc[-3::,5]

# %%
data1.columns

# %%
 data1[['Department_code','Item_name','Department']][6:11]

# %%
 data1.iloc[690,5] # .iloc เปลี่ยนมุมมองเป็น np.arry  ชี้เป็นเเถว คอลัม ติดลบ สไลด์ได้

# %%
 data1.iloc[-6,5]

# %% [markdown]
# ##มุมมองแบบArray

# %%
data1.iloc[0,0]

# %%
data1.iloc[-6,5]

# %%
data1.tail(7)

# %% [markdown]
# # Table Slicing
# ไม่ค่อยมีประสิทธิภาพ
# ต้องทราบพิกัด

# %%
data1.iloc[-20 :,7:10]

# %% [markdown]
#  ## table Query

# %% [markdown]
# Quiz3
# ####อยากได้รายการที่อนุมัติงบมากกว่า1,000,000 บาท แต่ไม่เกิน 2 ล้านบาท
# df [logics]Ffpmuj logics จะต้องมีจำนวนแถว = df

# %%
data1[(data1['Approved_buget'] >1000000) & (data1['Approved_buget']<=2000000)]

# %%
small_df=data1.iloc[-5:,:]
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
small_df[[False,True,True,False,False]]

# %% [markdown]
# #ปั้น list of  logics จากตาราง panda

# %%
small_df['Approved_buget']<1000000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-890bb46290ad> in <cell line: 1>()
# ----> 1 small_df['Approved_buget']<1000000
#
# NameError: name 'small_df' is not defined

# %%
small_df[small_df['Approved_buget']<1000000]

# %%
data1[data1['Approved_buget']<1000000] #ใช้ logi

# %%
data1['propertytype_name_en']== 'condo'

# %%
data1[data1['price_min'] > 10000000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price_min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-18a5f4dad7df> in <cell line: 1>()
# ----> 1 data1[data1['price_min'] > 10000000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'price_min'

# %%
data1[data1['price_min'] > 10000000].describe()

# %% [markdown]
# # Quiz 4
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
# 2. พื้นที่ และ จำนวนห้องนอนของบ้านที่แพงที่สุด
# 3. จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
# 4. ชนิดของบ้านที่แพงที่สุด
# 5. บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)].describe()
# Ans 3.928111e+06	 = 3.928111  ล้านบาท

# %%
price_mean = data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)]['price_min'].mean()

# %%
print(f'ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท คือ {int(price_mean):,}')

# %%
#2.พื้นที่และจำนวนห้องนอนของบ้านที่แพงที่สุด
data1['price_min'].max()

# %%
data1[data1['price_min']==580000000][['area_usable_min','count_room_bed']]

# %%
data1[data1['price_min']==data1['price_min'].max()][['area_usable_min','count_room_bed','price_min']]

# %%
data1[data1['price_min']==data1['price_min'].max()]

# %%
#3.จำนวนที่จอดรถและห้องน้ำที่ถูกที่สุด
data1['price_min'].min()

# %%
data1[data1['price_min']==100000][['count_parking','count_room_bath']]

# %%
data1[data1['price_min']==data1['price_min'].min()][['propertytype_name_en','count_parking','count_room_bath','price_min']]

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1.describe()
data1[data1['price_min'] == 580000000]
# Ans Condo

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1['propertytype_name_en'][data1['price_min'] == 580000000]

# %%
data1[data1['price_min']==data1['price_min'].max()][['propertytype_name_en','price_min']]

# %%
#5. บ้านชนิดไหนมีปริมาณมากที่สุด
data1['propertytype_name_en'].describe()

# %%
import os

# %%
path = '/content/drive/My Drive/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')
print(covid_file_path)

# %%
a = path + '/pm-18-jan-2021.csv'
print(a)

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid

# %%
data_covid.head()

# %% [markdown]
# NaN = Not a Number

# %%
data_covid.head(20)

# %%
data_covid.tail()

# %%
data_covid.shape

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset']

# %%
data_covid['risk'][12649]

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]

# %% [markdown]
# # เรียนถึงนี่ 12 Jan 2022

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['province_of_onset','announce_date','risk']]
smaller_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-eb3ea9803d98> in <cell line: 1>()
# ----> 1 smaller_table = data_covid[['province_of_onset','announce_date','risk']]
#       2 smaller_table
#
# NameError: name 'data_covid' is not defined

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ```pddf```[list_of_logical_values] คือการเลือก row ที่ logical values เป็น True

# %%
data_covid['province_of_onset']

# %%
data_covid['province_of_onset']=='ขอนแก่น'

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']

# %%
data_covid[data_covid['age']>=70]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,3:] # ตารางตัวอย่าง
eight_rows_covid

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ list ที่ มีค่า logic ของ แต่ละ row โดยที่ ค่า True คือ เลือก ค่า False คือไม่เลืิอก

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน

# %%
eight_rows_covid['district_of_onset'] == 'เมือง'

# %%
import numpy as np

# %% [markdown]
# $.isnull()$ ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
eight_rows_covid['district_of_onset'].isnull()

# %%
sum(eight_rows_covid['district_of_onset'].isnull())

# %% [markdown]
# Quiz (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของ**ผู้ชาย** ในข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของ**ผู้ชาย** ในจังหวัดขอนแก่น
# 3.   หาจำนวนผู้ป่วยที่เป็นคน **ที่ไม่ใช่คนไทย**

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data

# %%
female = this_data[this_data['sex']=='หญิง']
female

# %%
female['age']

# %%
sum = 0
N = 0
for a in female['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')

# %%
female[(female['province_of_onset']=='ขอนแก่น') | (female['province_of_onset']=='หนองคาย')]

# %% [markdown]
# #### หาจำนวนคนป่วยที่ไม่ใช่คนไทย

# %%
import numpy as np

# %%
np.sum(data_covid['nationality'].dropna() != 'Thailand')

# %% [markdown]
# #การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %%
data1.shape

# %%
data1.dropna().shape

# %%
data1.dropna(subset=['Fiscal_year']).shape

# %%
data1.isnull().any()

# %%
data1_1=data1.dropna(subset=['Fiscal_year']).shape
data1_1

# %%
data1_1.isnull().any()

# %% [markdown]
# ##Fill NA

# %%
set(data1['Core_budget_code' ])

# %%
data1.fillna('-',inplace =True)

# %%
set(data1['Core_budget_code' ])

# %% [markdown]
# #HW3
# 1.  รายการที่แพงและถูกที่สุดคือรายการไหน
# 2. รายการขุดลอกคูคลองของ 'สำนักงานเขตคลองสาน' และ 'สำนักงานเขตคลองสามวา'
# 3. จากข้อ 2 เขตไหนใช้งบประมาณเยอะกว่ากัน
# 4. Core Budget ไหน ('12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม', '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร','28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต') มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด

# %%
data1

# %% [markdown]
# ##ข้อที่1 รายการที่แพงและถูกที่สุดคือรายการไหน

# %%
data1['Approved_buget'].max()

# %%
data1['Approved_buget'].min()

# %%
data1[(data1['Approved_buget']==28500000) | (data1['Approved_buget']==0)]

# %%
print('รายการที่แพงที่สุดคือรายการที่ 576 ซึ่งมีงบ',A ,'บาท และมีรายการที่ถูกที่สุดคือ 612,613,631 ซึ่งมีงบ', B,'บาท')

# %% [markdown]
#  ##ข้อที่2 รายการขุดลอกคูคลองของ 'สำนักงานเขตคลองสาน' และ 'สำนักงานเขตคลองสามวา'

# %%
sm_1=data1[['Department','Item_name','Approved_buget']]

# %%
sm_1['Department']=='สำนักงานเขตคลองสาน'

# %%
sm_1['Department']=='สำนักงานเขตคลองสามวา'

# %%
C=sm_1[sm_1['Department']=='สำนักงานเขตคลองสาน']

# %%
D=sm_1[sm_1['Department']=='สำนักงานเขตคลองสามวา']

# %%
sm_1[(sm_1['Department']=='สำนักงานเขตคลองสาน' ) | ( sm_1['Department']=='สำนักงานเขตคลองสามวา')]

# %% [markdown]
# ##ข้อ3 จากข้อ 2 เขตไหนใช้งบประมาณเยอะกว่ากัน

# %%
C['Approved_buget'].sum()

# %%
D['Approved_buget'].sum()

# %%
print('สำนักงานเขตคลองสามวาใช้ไป',D['Approved_buget'].sum(),'บาท ซึ่งใช้เยอะกว่าเขตสำนักงานเขตคลองสานที่ใช้ไป',C['Approved_buget'].sum(),'บาท')

# %% [markdown]
# ##ข้อ4 Core Budget ไหน ('12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม', '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร','28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต') มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด

# %% [markdown]
# 12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม'

# %%
data1['Core_budget_code']=='12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม'

# %%
E=data1[data1['Core_budget_code']=='12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม']

# %%
sum = 0
N = 0
for a in E['Approved_buget']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'งบเฉลี่ย ของ 12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วมคือ {sum/N} บาท')

# %% [markdown]
# '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร'

# %%
data1['Core_budget_code']== '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร'

# %%
F=data1[data1['Core_budget_code']=='17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร']

# %%
sum = 0
N = 0
for a in F['Approved_buget']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'งบเฉลี่ย ของ 17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานครคือ {sum/N} บาท')

# %% [markdown]
# '28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต'

# %%
data1['Core_budget_code']=='28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต'

# %%
G=data1[data1['Core_budget_code']=='28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต']

# %%
sum = 0
N = 0
for a in G['Approved_buget']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขตคือ {sum/N} บาท')

# %%
sum = 0
N = 0
for a in F['Approved_buget']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1
print(F'งบเฉลี่ย ของ 17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานครมากที่สุด คือ {sum/N} บาท')

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data

# %%
this_data.shape #(12423, 3)

# %%
this_data.dropna()

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)

# %%
this_data.dropna(subset=['age','sex'])

# %%
print(this_data.dropna().shape)
print(this_data.dropna(subset=['sex','age']).shape)

# %% [markdown]
# # ตรวจสอบ Missing (```isnull()```)

# %%
data1.isnull().any()

# %%
data1.isnull().all()

# %%
data1.isnull().any().any()

# %%
this_data.isnull().any() # .any() เอาค่าความจริงใน column มา OR กัน

# %%
this_data.isnull().all() # .all() เอาค่าความจริงใน column มา AND กัน

# %%
this_data.isnull().any().any()

# %%
this_data.dropna(subset=['sex','age']).isnull().any()

# %%
this_data.dropna(subset=['sex','age'])

# %% [markdown]
# ### 1. เพื่อให้ได้ผลลัพธ์การจัดการ ```dropna()``` ต้องเอาตัวแปรมารับ

# %%
this_data_nonull = this_data.dropna(subset=['sex','age'])

# %%
this_data_nonull.isnull().any()

# %% [markdown]
# ### 2. update ตารางด้วยตัวแปร ```inplace```

# %%
this_data.dropna(subset=['sex','age'],inplace=True)

# %%
this_data.isnull().any()

# %%
aa = this_data.dropna(subset=['sex','age'],inplace=True)

# %%
aa

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna()```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')

# %% [markdown]
# ### 1. แทนด้วย class ใหม่

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-99, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()

# %%
this_data_updated.tail(15)

# %%
this_data_updated.isnull().any()

# %% [markdown]
# ### 2. แทนด้วยค่าที่เหมาะสม
#
#
# *   ตามใจคนทำ
# *   ค่ากลาง

# %% [markdown]
# #### ตามใจคนทำ

# %%
data_covid.head()

# %%
data_covid_fillasiwant = data_covid.fillna(value={'sex':'หญิง'})  #เรามีข้อมูลว่า เพศหญิงมีเยอะกว่าเพศชาย

# %%
data_covid_fillasiwant.isnull().any()

# %% [markdown]
# #### แทนด้วยค่ากลาง

# %%
data_covid['age']

# %%
data_covid['age'].mean()

# %%
data_covid_fillwithmean = data_covid.fillna(value={'age':data_covid['age'].mean()})

# %%
data_covid_fillwithmean.isnull().any()

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
for row_i in range(len(data1)):
     print(data1.iloc[row_i,-2:])
     print('----------------------')

# %%
for row in data1.iterrows():
  #print(row)
  print(row[1]['Fiscal_year'])
  print('_______________')
# Out:
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 62
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 63
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 64
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 65
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________
# 66
# _______________

# %% [markdown]
# ##การสร้าง columns เพิ่ม
# df['ชื่อ column ใหม่'] = list of data #list of data มีจำนวนสมาชิกเท่ากับจำนวน row ของตาราง

# %%
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
small_df['ผู้รับผิดชอบ'] = ['ลุงตู่','ลุงป้อม','ชัชชาติ','พิธา']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-a8e00cb60154> in <cell line: 1>()
# ----> 1 small_df ['ผู้รับผิดชอบ'] =['ลุงตู่','ลุงป้อม','ชัชชาติ','พิธา']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
#    4916         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (5)

# %%
small_df['ผู้รับผิดชอบ'] = ['ลุง','พิธา','ชัชชาติ','ป้อม','ปชต']
# Out:
# <ipython-input-47-15530de9214a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['ผู้รับผิดชอบ'] = ['ลุง','พิธา','ชัชชาติ','ป้อม','ปชต']

# %% [markdown]
# ##การลบคอลัม

# %%
small_df.drop(axis=1,columns=['Core_budget_code'])
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              งบลงทุน
# 691     สำนักงานเขตบางบอน              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
new_column = list()
for row in data1.iterrows():
  new_col = f"{row[1]['Department']}-{row[1]['Expenditure_category']}-{row[1]['Item_name']}"
  new_column.append(new_col)
  print(new_column )
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี', 'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50', 'สำนักงานเขตจตุจักร-งบลงทุน-ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลาดยาว', 'สำนักงานเขตราชเทวี-งบลงทุน-ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคลองแสนแสบ', 'สำนักงานเขตบางพลัด-งบลงทุน-ขุดลอกคลองวัดดาวดึงษาราม', 'สำนักงานเขตดินแดง-งบลงทุน-ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึงคลองห้วยขวาง', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประดิษฐ์)', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างบ้านบางแค 2', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองหลวงพ่อบ้านแหลม', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกคลองผู้ใหญ่เส็ง 1', 'สำนักงานเขตบางแค-งบลงทุน-ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยาราชมนตรี', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธนบุรีรมย์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แขวงโคกแฝด', 'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระทุ่มราย', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนามแดง', 'สำนักงานเขตหนองแขม-งบลงทุน-ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะที่กำหนดให้', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต่ถนนวิภาวดีรังสิตถึงสุดระยะที่กำหนด', 'สำนักงานเขตดอนเมือง-งบลงทุน-ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาวดีรังสิตถึงสะพานทางเข้าบริษัทไทยเทยิ่น', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองจรเข้ขบจากคลองประเวศบุรีรมย์\nถึงคลองมะขามเทศ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองซอยจากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเสาหินจากถนนพระราม 3   \nถึงสุดระยะที่กำหนดให้', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองวังเดิมจากคลองมอญ \nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองตาหนังจากคลองลำเจียก\nถึงคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางคูเวียงจากคลองขุนศรีบุรีรักษ์\nถึงคลองทวีวัฒนา', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองปักหลักจากคลองจรเข้ขบ\nถึงคลองอาจารย์พร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองมอญจากแม่น้ำเจ้าพระยา\nถึงคลองบางกอกใหญ่', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองสามเสนจากคลองแยกเข้าบึงมักกะสัน\nถึงสถานีสูบน้ำคลองสามเสนตอนคลองแสนแสบ', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางโคลัดจากคลองวัดสิงห์\nถึงคลองรางขี้เหล็ก', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงเอกมัย', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเจ้าคุณสิงห์จากบริเวณ\nซอยลาดพร้าว 87 ถึงทางเข้าหมู่บ้านธารารมณ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองขุนศรีบุรีรักษ์จากคลองมหาสวัสดิ์ \nถึงคลองบางพรม', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงแอนเน็กซ์และคูระบายน้ำ\nซอยแอนเน็กซ์', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำเจียรดับจากคลองแสนแสบ\nถึงคลองลำต้นไทร', 'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบุปผารามจากคลองบางกอกใหญ่\nถึงคลองสมเด็จเจ้าพระยา', 'สำนักงานเขตบางกะปิ-งบลงทุน-ขุดลอกคลองสะพานสูง จาก ...

# %%
data1['desciption']=new_column
data1=data1.drop(axis=1,columns=['Department','Expenditure_category','Item_name'])
